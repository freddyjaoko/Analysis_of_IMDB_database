# %%
import pandas as pd
import sqlite3

# %%
conn = sqlite3.connect('Db-IMDB-Assignment.db')

# %% [markdown]
# Listing all the directors who directed a 'Comedy' movie in a leap year. It should return director name, the movie name, and the year.

# %%
#finding the index of the row with the value "comedy" in the "Genre" column

genres = pd.read_sql_query("SELECT * FROM Genre LIMIT 20", conn)
genres

#comedy genre id=10
# Out:
#     index                                    Name  GID
# 0       0   Adventure, Drama, Fantasy                0
# 1       1       Action, Comedy, Crime                1
# 2       2  Action, Adventure, Fantasy                2
# 3       3   Action, Adventure, Sci-Fi                3
# 4       4     Drama, Horror, Thriller                4
# 5       5              Drama, Romance                5
# 6       6     Comedy, Crime, Thriller                6
# 7       7            Biography, Drama                7
# 8       8       Comedy, Drama, Family                8
# 9       9    Action, Sci-Fi, Thriller                9
# 10     10                      Comedy               10
# 11     11               Drama, Sci-Fi               11
# 12     12            Action, Thriller               12
# 13     13      Action, Comedy, Sci-Fi               13
# 14     14              Comedy, Horror               14
# 15     15           Action, Adventure               15
# 16     16               Comedy, Drama               16
# 17     17       Crime, Drama, History               17
# 18     18    Adventure, Comedy, Drama               18
# 19     19                       Drama               19

# %%
#finding movies made in a leap year

leapyear = pd.read_sql_query("SELECT title, MID, Year FROM Movie WHERE (Year % 4 = 0 AND Year % 100 != 0) OR (Year % 400 = 0)", conn)
leapyear
# Out:
#                           title        MID    year
# 0                  The Avengers  tt0848228    2012
# 1    Captain America: Civil War  tt3498820    2016
# 2                          Lion  tt3741834    2016
# 3           Slumdog Millionaire  tt1010048    2008
# 4                          2012  tt1190080  I 2009
# ..                          ...        ...     ...
# 940                      Fakira  tt0298327    1976
# 941                 Le Halua Le  tt2356426    2012
# 942                    Ram Raaj  tt2971560    2008
# 943           Goa Dalli CID 999  tt0290632    1968
# 944           Raja Aur Rangeeli  tt0363011    1996
#
# [945 rows x 3 columns]

# %%
#finding movie id of movies in the comedy genre

comedy =pd.read_sql_query("SELECT MID FROM M_Genre WHERE GID = 10", conn)
comedy
# Out:
#            MID
# 0    tt3726012
# 1    tt8852558
# 2    tt7526836
# 3    tt7881542
# 4    tt5842616
# ..         ...
# 102  tt0268489
# 103  tt0414503
# 104  tt0398404
# 105  tt0227496
# 106  tt0438153
#
# [107 rows x 1 columns]

# %%
#merging the comedy and leapyear dataframes on "MID" to get a list of all the comedy movies released in a leap year

df_comedy = pd.merge(leapyear,comedy,on="MID", how= 'inner')
df_comedy
# Out:
#                                title        MID    year
# 0                         Mastizaade  tt3726012    2016
# 1               Kyaa Kool Hain Hum 3  tt5290620    2016
# 2       Luv Shuv Tey Chicken Khurana  tt2186933    2012
# 3                          Thank You  tt1720254  I 2011
# 4                      Saat Uchakkey  tt5637188    2016
# 5                         Filmistaan  tt2417560    2012
# 6                     Days of Tafree  tt5909308    2016
# 7      Tere Bin Laden: Dead Or Alive  tt5313980    2016
# 8                    Papa Kahte Hain  tt0246839    1996
# 9           Kyaa Super Kool Hain Hum  tt2027138    2012
# 10              Navra Mazha Navsacha  tt0833510    2004
# 11                         Maalamaal  tt0300160    1988
# 12                 Will You Marry Me  tt3407604    2012
# 13  Mere Dost Picture Abhi Baaki Hai  tt2232524    2012
# 14               Mr Bhatti on Chutti  tt1127220    2012
# 15                            Bumboo  tt2265191    2012
# 16         Motu Patlu: King of Kings  tt6278732    2016
# 17                     Challo Driver  tt2251552    2012
# 18                       Mr. Bechara  tt0117099    1996
# 19              Life Ki Toh Lag Gayi  tt2327389    2012
# 20          Daal Mein Kuch Kaala Hai  tt2190256    2012
# 21                 Kis Kis Ki Kismat  tt0442799    2004
# 22                    Ab Ayega Mazaa  tt0178211    1984
# 23                  Ek Hota Vidushak  tt0251067    1992
# 24                      Paisa Vasool  tt0396782    2004
# 25                  Shaadi Ka Laddoo  tt0414503    2004
# 26                       Let's Enjoy  tt0438153    2004

# %%
#loading the directors id in a dataframe

directors = pd.read_sql_query("SELECT MID, PID FROM M_director", conn)
directors
# Out:
#             MID        PID
# 0     tt2388771  nm0785227
# 1     tt5164214  nm0002657
# 2     tt1365519  nm1012385
# 3     tt0848228  nm0923736
# 4     tt8239946  nm9751348
# ...         ...        ...
# 3468  tt0090611  nm0220823
# 3469  tt0106270  nm0613517
# 3470  tt0852989  nm2312263
# 3471  tt0375882  nm0066829
# 3472  tt0375890  nm1421793
#
# [3473 rows x 2 columns]

# %%
#merging df_comedy and directors dataframes on "PID"

df_directors = pd.merge(df_comedy,directors,on="MID", how= 'inner')
df_directors
# Out:
#                                title        MID    year        PID
# 0                         Mastizaade  tt3726012    2016  nm1179457
# 1               Kyaa Kool Hain Hum 3  tt5290620    2016  nm1207750
# 2       Luv Shuv Tey Chicken Khurana  tt2186933    2012  nm1343477
# 3                          Thank You  tt1720254  I 2011  nm0063357
# 4                      Saat Uchakkey  tt5637188    2016  nm0788916
# 5                         Filmistaan  tt2417560    2012  nm2859182
# 6                     Days of Tafree  tt5909308    2016  nm7630832
# 7      Tere Bin Laden: Dead Or Alive  tt5313980    2016  nm0788855
# 8                    Papa Kahte Hain  tt0246839    1996  nm0080315
# 9           Kyaa Super Kool Hain Hum  tt2027138    2012  nm1966139
# 10              Navra Mazha Navsacha  tt0833510    2004  nm0755113
# 11                         Maalamaal  tt0300160    1988  nm1077919
# 12                 Will You Marry Me  tt3407604    2012  nm2024446
# 13  Mere Dost Picture Abhi Baaki Hai  tt2232524    2012  nm1186435
# 14               Mr Bhatti on Chutti  tt1127220    2012  nm0713615
# 15                            Bumboo  tt2265191    2012  nm3796324
# 16         Motu Patlu: King of Kings  tt6278732    2016  nm5082788
# 17                     Challo Driver  tt2251552    2012  nm5148918
# 18                       Mr. Bechara  tt0117099    1996  nm0080180
# 19              Life Ki Toh Lag Gayi  tt2327389    2012  nm3896655
# 20          Daal Mein Kuch Kaala Hai  tt2190256    2012  nm0051091
# 21                 Kis Kis Ki Kismat  tt0442799    2004  nm1323642
# 22                    Ab Ayega Mazaa  tt0178211    1984  nm0660967
# 23                  Ek Hota Vidushak  tt0251067    1992  nm0665374
# 24                      Paisa Vasool  tt0396782    2004  nm1394996
# 25                  Shaadi Ka Laddoo  tt0414503    2004  nm0442472
# 26                       Let's Enjoy  tt0438153    2004  nm0474891

# %%
#merging the movie and director names data frames

director_names = pd.read_sql_query("SELECT PID, Name FROM Person", conn)
director_names
# Out:
#              PID                   Name
# 0      nm0000288         Christian Bale
# 1      nm0000949         Cate Blanchett
# 2      nm1212722   Benedict Cumberbatch
# 3      nm0365140          Naomie Harris
# 4      nm0785227            Andy Serkis
# ...          ...                    ...
# 37561  nm2182643           Kamika Verma
# 37562  nm1029114     Dhorairaj Bhagavan
# 37563  nm3769883           Nasir Shaikh
# 37564  nm1470989                 Kannan
# 37565  nm0298158           Adrian Fulle
#
# [37566 rows x 2 columns]

# %%
#merging df_direcors and directors_names to get a dataframe of all the comedy movies made in a leapyear and their directors

df_directorsnames = pd.merge(df_directors, director_names, on='PID')

df_directorsnames
# Out:
#                                title        MID    year        PID
# 0                         Mastizaade  tt3726012    2016  nm1179457  \
# 1               Kyaa Kool Hain Hum 3  tt5290620    2016  nm1207750
# 2       Luv Shuv Tey Chicken Khurana  tt2186933    2012  nm1343477
# 3                          Thank You  tt1720254  I 2011  nm0063357
# 4                      Saat Uchakkey  tt5637188    2016  nm0788916
# 5                         Filmistaan  tt2417560    2012  nm2859182
# 6                     Days of Tafree  tt5909308    2016  nm7630832
# 7      Tere Bin Laden: Dead Or Alive  tt5313980    2016  nm0788855
# 8                    Papa Kahte Hain  tt0246839    1996  nm0080315
# 9           Kyaa Super Kool Hain Hum  tt2027138    2012  nm1966139
# 10              Navra Mazha Navsacha  tt0833510    2004  nm0755113
# 11                         Maalamaal  tt0300160    1988  nm1077919
# 12                 Will You Marry Me  tt3407604    2012  nm2024446
# 13  Mere Dost Picture Abhi Baaki Hai  tt2232524    2012  nm1186435
# 14               Mr Bhatti on Chutti  tt1127220    2012  nm0713615
# 15                            Bumboo  tt2265191    2012  nm3796324
# 16         Motu Patlu: King of Kings  tt6278732    2016  nm5082788
# 17                     Challo Driver  tt2251552    2012  nm5148918
# 18                       Mr. Bechara  tt0117099    1996  nm0080180
# 19              Life Ki Toh Lag Gayi  tt2327389    2012  nm3896655
# 20          Daal Mein Kuch Kaala Hai  tt2190256    2012  nm0051091
# 21                 Kis Kis Ki Kismat  tt0442799    2004  nm1323642
# 22                    Ab Ayega Mazaa  tt0178211    1984  nm0660967
# 23                  Ek Hota Vidushak  tt0251067    1992  nm0665374
# 24                      Paisa Vasool  tt0396782    2004  nm1394996
# 25                  Shaadi Ka Laddoo  tt0414503    2004  nm0442472
# 26                       Let's Enjoy  tt0438153    2004  nm0474891
#
#                       Name
# 0             Milap Zaveri
# 1             Umesh Ghadge
# 2            Sameer Sharma
# 3             Anees Bazmee
# 4           Sanjeev Sharma
# 5             Nitin Kakkar
# 6        Krishnadev Yagnik
# 7          Abhishek Sharma
# 8             Mahesh Bhatt
# 9             Sachin Yardi
# 10                  Sachin
# 11            Kawal Sharma
# 12             Aditya Datt
# 13          Rajnish Thakur
# 14            Karan Razdan
# 15      Jagdish Rajpurohit
# 16             Suhas Kadav
# 17        Vickrant Mahajan
# 18               Bhagyaraj
# 19            Rakesh Mehta
# 20            Anand Balraj
# 21            Govind Menon
# 22         Pankaj Parashar
# 23            Jabbar Patel
# 24       Srinivas Bhashyam
# 25             Raj Kaushal
# 26   Siddharth Anand Kumar

# %% [markdown]
# Listing the names of all the actors who played in the movie 'Anand' (1971)

# %%
#finding the movieid of the movie 'Anand'

anand_id = pd.read_sql_query("SELECT MID FROM Movie WHERE title = 'Anand'", conn)
anand_id
# Out:
#          MID
# 0  tt0066763

# %%
#Finding the PID of the cast who acted in Anand

actor_id = pd.read_sql_query("SELECT PID FROM M_Cast WHERE MID ='tt0066763'", conn)
actor_id
# Out:
#            PID
# 0    nm0004435
# 1    nm0000821
# 2    nm0764407
# 3    nm0219946
# 4    nm0219947
# 5    nm0783996
# 6    nm0222743
# 7    nm0695155
# 8    nm0474931
# 9    nm1783998
# 10   nm0080231
# 11   nm1587173
# 12   nm0667985
# 13   nm0451862
# 14   nm0802107
# 15   nm0907888
# 16   nm1425570

# %%
#Finding the names of the cast with the previous actor ids

df_cast = pd.read_sql_query("SELECT Name, PID FROM Person", conn)
df_cast
# Out:
#                         Name        PID
# 0             Christian Bale  nm0000288
# 1             Cate Blanchett  nm0000949
# 2       Benedict Cumberbatch  nm1212722
# 3              Naomie Harris  nm0365140
# 4                Andy Serkis  nm0785227
# ...                      ...        ...
# 37561           Kamika Verma  nm2182643
# 37562     Dhorairaj Bhagavan  nm1029114
# 37563           Nasir Shaikh  nm3769883
# 37564                 Kannan  nm1470989
# 37565           Adrian Fulle  nm0298158
#
# [37566 rows x 2 columns]

# %%
#merging the actors_cast and df_cast to get a dataframe of all the actors who played in the movie 'Anand' (1971)

df_cast_names = pd.merge(actor_id, df_cast, on='PID', how='inner')
df_cast_names
# Out:
# Empty DataFrame
# Columns: [PID, Name]
# Index: []
